# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Sentiment analysis con Embeddings + LSTM

# %% [markdown]
# ### Objetivo
# El objetivo es utilizar las críticas de compradores de ropa para que el sistema determine la evaluación del comprador y su crítica (cuantas estrellas le asigna al producto).

# %%
# !pip install --upgrade --no-cache-dir gdown --quiet

# %%
import numpy as np
import random
import io
import pickle
import pandas as pd
import os
import gdown
import logging
from pathlib import Path
from io import StringIO
import pickle

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
from tensorflow.keras import layers

from keras.utils.np_utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.text import Tokenizer 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# ### Datos
# Utilizaremos como dataset críticas de compradores de ropa (eCommerce) los cuales puntuaron a cada prenda con un puntaje de 1 a 5 estrellas.\
# Referencia del dataset: [LINK](https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews/version/1)

# %%
# Descargar la carpeta de dataset
if os.access('clothing_ecommerce_reviews.csv', os.F_OK) is False:
    url = 'https://drive.google.com/uc?id=1k2Dz4oY5uxI3JEaT6m-L2T2HvLkECYIP'
    output = 'clothing_ecommerce_reviews.csv'
    gdown.download(url, output, quiet=False)
else:
    print("El dataset ya se encuentra descargado")
# Out:
# El dataset ya se encuentra descargado

# %%
# Armar el dataset
df = pd.read_csv('clothing_ecommerce_reviews.csv')
df.drop(columns = ['Unnamed: 0'], inplace = True)
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# ### 1 - Limpieza de datos

# %% [markdown]
# #### Alumno:
# - Del dataset unicamente utilizar las columnas "Review Text" y "Rating.
# - Tranformar el rating 1-5 a una escala numérica de 0 a 4.

# %%
df_reviews = df.loc[:, ['Review Text', 'Rating']].dropna()
df_reviews['Rating'] = df_reviews['Rating'] - 1
df_reviews.head()
# Out:
#                                          Review Text  Rating
# 0  Absolutely wonderful - silky and sexy and comf...       3
# 1  Love this dress!  it's sooo pretty.  i happene...       4
# 2  I had such high hopes for this dress and reall...       2
# 3  I love, love, love this jumpsuit. it's fun, fl...       4
# 4  This shirt is very flattering to all due to th...       4

# %% [markdown]
# #### Alumno:
#
# Observar como está distribuido el dataset respecto a la columna Rating es decir, observar que tan balanceado se encuentra respecto a cada clase

# %%
# Alumno: Observar como está distribuido el dataset respecto a la columna Rating
# es decir, observar que tan balanceado se encuentra respecto a cada clase
balance_clases=df_reviews['Rating'].value_counts(normalize=True)
balance_clases
# Out:
# 4    0.553862
# 3    0.216775
# 2    0.124685
# 1    0.068416
# 0    0.036262
# Name: Rating, dtype: float64

# %%
sns.countplot(x='Rating', data=df_reviews)
plt.title("Balanceo de clases")
plt.xlabel("Rating")
plt.ylabel("Número de observaciones");
plt.show()

# %% [markdown]
# Vemos que las clases están bastante desbalanceadas

# %% [markdown]
# #### Alumno: tomar la columna de las review y almacenarlo todo en un vector numpy de reviews

# %%
rating_reviews = df_reviews['Review Text'].values
print("Shape del vecotr de reviews: ",rating_reviews.shape)
# Out:
# Shape del vecotr de reviews:  (22641,)

# %% [markdown]
# #### Alumno: Cuantas reviews (rows) hay para evaluar?

# %%
print("Cantidad de reviews a evaluar: ",len(rating_reviews))
# Out:
# Cantidad de reviews a evaluar:  22641

# %%
print("Las primeras 5 reviews son: \n")
rating_reviews[:5]
# Out:
# Las primeras 5 reviews son:
# array(['Absolutely wonderful - silky and sexy and comfortable',
#        'Love this dress!  it\'s sooo pretty.  i happened to find it in a store, and i\'m glad i did bc i never would have ordered it online bc it\'s petite.  i bought a petite and am 5\'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.',
#        'I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c',
#        "I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!",
#        'This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!'],
#       dtype=object)

# %% [markdown]
# #### Alumno: Concatenar todas las reviews para armar el corpus

# %%
corpus = ' '.join(rating_reviews)

# %% [markdown]
# #### Alumno: ¿Cuál es la longitud de ese corpus?

# %%
print("Longitud del corpus: ",len(corpus))
# Out:
# Longitud del corpus:  7011643

# %% [markdown]
# #### Alumno: Utilizar "text_to_word_sequence" para separar las palabras en tokens
#
# Recordar que text_to_word_sequence automaticamente quita los signos de puntuacion y pasa el texto a lowercase

# %%
tokens = text_to_word_sequence(corpus)

# %% [markdown]
# #### Alumno: Dar un vistazo a los primeros 20 tokens/palabras

# %%
print("Primeros 20 tokens:\n",tokens[:20])
# Out:
# Primeros 20 tokens:
#  ['absolutely', 'wonderful', 'silky', 'and', 'sexy', 'and', 'comfortable', 'love', 'this', 'dress', "it's", 'sooo', 'pretty', 'i', 'happened', 'to', 'find', 'it', 'in', 'a']

# %% [markdown]
# #### Alumno: ¿Cuántos tokens/palabras hay?

# %%
print("Cantidad de tokens: ",len(tokens))
# Out:
# Cantidad de tokens:  1372203

# %% [markdown]
# #### Alumno: Tokenizar las palabras con el Tokenizer de Keras
#
# - Definir una máxima cantidad de palabras a utilizar: num_words

# %%
num_words = 4000
vocab_size = num_words
tokenizador = Tokenizer(num_words=num_words)
tokenizador.fit_on_texts(tokens)

# %% [markdown]
# #### Alumno: Obtener el diccionario de palabra (word) a índice y observar la cantidad total del vocabulario

# %%
word_index = tokenizador.word_index
print("Cantidad total del vocabulario: ",len(word_index))
# Out:
# Cantidad total del vocabulario:  14847

# %% [markdown]
# #### Alumno: Convertir las palabras/tokens a números

# %%
reviews_nums = tokenizador.texts_to_sequences(rating_reviews)

# %%
print("Para el review: '",rating_reviews[0], "' su representación númerica es: ", reviews_nums[0])
# Out:
# Para el review: ' Absolutely wonderful - silky and sexy and comfortable ' su representación númerica es:  [253, 532, 917, 3, 662, 3, 68]

# %% [markdown]
# #### Alumno: Determinar cual es la oración más larga

# %%
long_max =max(len(s) for s in reviews_nums)
print("La oracion más larga tiene ",long_max, " palabras")
# Out:
# La oracion más larga tiene  115  palabras

# %% [markdown]
# #### Alumno: Realizar padding de las sentencias al mismo tamaño tomando de referencia la máxima sentencia

# %%
 X = pad_sequences(reviews_nums, padding='pre', maxlen=long_max)

# %% [markdown]
# #### Alumno: Observar las dimensiones de la variable input

# %%
print("Dimensiones de la variable input(x): ",X.shape)
# Out:
# Dimensiones de la variable input(x):  (22641, 115)

# %% [markdown]
# #### Alumno tomar la columna rating y alcemacenarla en una variable "y" transformada a oneHotEncoding
# Su shape debe ser equivalente la cantidad de rows del corpus y a la cantidad de clases que se deseen predecir (en este ejemplo son 5)

# %%
y = to_categorical(df_reviews['Rating'].values)

# %%
print("Dimensiones de la variable output(y): ",y.shape)
# Out:
# Dimensiones de la variable output(y):  (22641, 5)

# %% [markdown]
# #### Alumno: Dividir los datos en train y test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=18)

# %% [markdown]
# #### Alumno: determinar la dimensiones de entrada y salida

# %%
in_shape = X.shape[1]
out_shape = y.shape[1]
print("Dimensiones de entrada: ",in_shape)
print("Dimensiones de salida: ",out_shape)
# Out:
# Dimensiones de entrada:  115
# Dimensiones de salida:  5

# %% [markdown]
# ### 2 - Entrenar el modelo con Embeddings + LSTM

# %% [markdown]
# #### Alumno: Entrene su modelo con LSTM entrenando sus propios embeddings o utilizando embeddings pre-entrenados.

# %% [markdown]
# #### 2.1 - Entrenar el modelo con Embeddings + LSTM con embedings propios

# %% [markdown]
# ##### Generamos nuestro modelo 1
#
# El mismo consta de:
#
# * Capa de embedings con tamaño de embeding de 60
# * Capa LSTM de 64 unidades Bidireccional
# * Capa LSTM de 96 unidades
# * Capa densa de 128 unidades
# * Capa densa final con activación Softmax y tamaño de salida de 5 (5 clases)

# %%
model = Sequential()
tam_embed = 150
model.add(Embedding(input_dim=vocab_size+1, output_dim=tam_embed, input_length=in_shape))
model.add(Bidirectional(LSTM(units=64, return_sequences=True)))
model.add(Dropout(0.15))
model.add(LSTM(units=96)) 

model.add(Dense(units=128, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(units=out_shape, activation='softmax'))

model.compile(optimizer="adam",
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 115, 150)          600150
#
#  bidirectional (Bidirectiona  (None, 115, 128)         110080
#  l)
#
#  dropout (Dropout)           (None, 115, 128)          0
#
#  lstm_1 (LSTM)               (None, 96)                86400
#
#  dense (Dense)               (None, 128)               12416
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 809,691
# Trainable params: 809,691
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
epochs = 60
hist = model.fit(X_train, y_train, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/60
# 453/453 [==============================] - 18s 23ms/step - loss: 1.0003 - accuracy: 0.5978 - val_loss: 0.9410 - val_accuracy: 0.6172
# Epoch 2/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.8458 - accuracy: 0.6422 - val_loss: 0.8638 - val_accuracy: 0.6232
# Epoch 3/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.7557 - accuracy: 0.6784 - val_loss: 0.9128 - val_accuracy: 0.6467
# Epoch 4/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.6856 - accuracy: 0.7126 - val_loss: 0.9092 - val_accuracy: 0.6238
# Epoch 5/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.6263 - accuracy: 0.7408 - val_loss: 0.9864 - val_accuracy: 0.5885
# Epoch 6/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.5611 - accuracy: 0.7728 - val_loss: 1.0333 - val_accuracy: 0.5932
# Epoch 7/60
# 453/453 [==============================] - 10s 21ms/step - loss: 0.5169 - accuracy: 0.7965 - val_loss: 1.1125 - val_accuracy: 0.6227
# Epoch 8/60
# 453/453 [==============================] - 10s 23ms/step - loss: 0.4478 - accuracy: 0.8253 - val_loss: 1.1638 - val_accuracy: 0.6111
# Epoch 9/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0
epoch_count = range(1, len(hist.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_accuracy'], label='valid')
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 142/142 [==============================] - 1s 10ms/step - loss: 3.7377 - accuracy: 0.5597
# [3.7377076148986816, 0.5597262382507324]

# %% [markdown]
# ##### Generamos nuestro modelo 2
#
# El mismo consta de:
#
# * Capa de embedings con tamaño de embeding de 100
# * 2 Capas LSTM de 128 unidades Bidireccional
# * Una capa LSTM de 64 unidades Bidireccional
# * Capa densa de 32 unidades
# * Capa densa final con activación Softmax y tamaño de salida de 5 (5 clases)

# %%
model2 = Sequential()
tam_embed = 100
model2.add(Embedding(input_dim=vocab_size+1, output_dim=tam_embed, input_length=in_shape))
model2.add(Bidirectional(LSTM(units=128, return_sequences=True)))
model2.add(Dropout(0.15))
model2.add(Bidirectional(LSTM(units=128, return_sequences=True)))
model2.add(Dropout(0.2))
model2.add(Bidirectional(LSTM(units=64)))

model2.add(Dense(units=32, activation='relu'))
model2.add(Dropout(rate=0.2))
model2.add(Dense(units=out_shape, activation='softmax'))

model2.compile(optimizer="adam",
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 115, 100)          400100
#
#  bidirectional_1 (Bidirectio  (None, 115, 256)         234496
#  nal)
#
#  dropout_2 (Dropout)         (None, 115, 256)          0
#
#  bidirectional_2 (Bidirectio  (None, 115, 256)         394240
#  nal)
#
#  dropout_3 (Dropout)         (None, 115, 256)          0
#
#  bidirectional_3 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 1,197,481
# Trainable params: 1,197,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model2, to_file='model_plot2.png', show_shapes=True, show_layer_names=True)

# %%
hist2 = model2.fit(X_train, y_train, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/60
# 453/453 [==============================] - 31s 49ms/step - loss: 1.0537 - accuracy: 0.5789 - val_loss: 0.9003 - val_accuracy: 0.6241
# Epoch 2/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.8832 - accuracy: 0.6321 - val_loss: 0.8855 - val_accuracy: 0.6445
# Epoch 3/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.8172 - accuracy: 0.6595 - val_loss: 0.8740 - val_accuracy: 0.6249
# Epoch 4/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.7597 - accuracy: 0.6818 - val_loss: 0.8999 - val_accuracy: 0.6359
# Epoch 5/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.7038 - accuracy: 0.7054 - val_loss: 0.9183 - val_accuracy: 0.6232
# Epoch 6/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.6555 - accuracy: 0.7230 - val_loss: 0.9720 - val_accuracy: 0.5904
# Epoch 7/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.6280 - accuracy: 0.7397 - val_loss: 1.0111 - val_accuracy: 0.6105
# Epoch 8/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.5759 - accuracy: 0.7684 - val_loss: 1.1557 - val_accuracy: 0.6354
# Epoch 9/60
# 453/453 [==============================] - 21s 47ms/step - loss: 0.5572 - accuracy: 0.7779 - val_loss: 1.0658 - val_accuracy: 0.5990
# Epoch 10/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.5112 - accuracy: 0.8002 - val_loss: 1.1008 - val_accuracy: 0.6061
# Epoch 11/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.4667 - accuracy: 0.8197 - val_loss: 1.2751 - val_accuracy: 0.6003
# Epoch 12/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.4249 - accuracy: 0.8397 - val_loss: 1.2985 - val_accuracy: 0.5907
# Epoch 13/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.4053 - accuracy: 0.8482 - val_loss: 1.3843 - val_accuracy: 0.5948
# Epoch 14/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.3740 - accuracy: 0.8622 - val_loss: 1.5326 - val_accuracy: 0.6006
# Epoch 15/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.3373 - accuracy: 0.8788 - val_loss: 1.4209 - val_accuracy: 0.5934
# Epoch 16/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.3141 - accuracy: 0.8871 - val_loss: 1.4920 - val_accuracy: 0.5702
# Epoch 17/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0
60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0533 - accuracy: 0.9848 - val_loss: 3.1748 - val_accuracy: 0.5587
# Epoch 45/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.0530 - accuracy: 0.9834 - val_loss: 3.1847 - val_accuracy: 0.5766
# Epoch 46/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0382 - accuracy: 0.9887 - val_loss: 3.3392 - val_accuracy: 0.5799
# Epoch 47/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0426 - accuracy: 0.9870 - val_loss: 3.0604 - val_accuracy: 0.5783
# Epoch 48/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0515 - accuracy: 0.9852 - val_loss: 2.8023 - val_accuracy: 0.5857
# Epoch 49/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0530 - accuracy: 0.9843 - val_loss: 3.0533 - val_accuracy: 0.5813
# Epoch 50/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0288 - accuracy: 0.9912 - val_loss: 3.4042 - val_accuracy: 0.5725
# Epoch 51/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.0398 - accuracy: 0.9888 - val_loss: 3.3542 - val_accuracy: 0.5796
# Epoch 52/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0326 - accuracy: 0.9908 - val_loss: 3.3801 - val_accuracy: 0.5879
# Epoch 53/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0324 - accuracy: 0.9906 - val_loss: 3.4545 - val_accuracy: 0.5785
# Epoch 54/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0536 - accuracy: 0.9847 - val_loss: 3.2881 - val_accuracy: 0.5741
# Epoch 55/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0405 - accuracy: 0.9896 - val_loss: 3.4191 - val_accuracy: 0.5719
# Epoch 56/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0318 - accuracy: 0.9910 - val_loss: 3.4850 - val_accuracy: 0.5755
# Epoch 57/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.0249 - accuracy: 0.9930 - val_loss: 3.6628 - val_accuracy: 0.5783
# Epoch 58/60
# 453/453 [==============================] - 20s 45ms/step - loss: 0.0347 - accuracy: 0.9903 - val_loss: 3.3946 - val_accuracy: 0.5777
# Epoch 59/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0297 - accuracy: 0.9914 - val_loss: 3.5556 - val_accuracy: 0.5824
# Epoch 60/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0276 - accuracy: 0.9925 - val_loss: 3.5594 - val_accuracy: 0.5783

# %%
epoch_count = range(1, len(hist2.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist2.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist2.history['val_accuracy'], label='valid')
plt.show()

# %%
model2.evaluate(X_test, y_test)
# Out:
# 142/142 [==============================] - 3s 18ms/step - loss: 3.7295 - accuracy: 0.5584
# [3.7295355796813965, 0.5584014058113098]

# %% [markdown]
# En ambos modelos se obtuvieron resultado similares. En train se obtuvieron muy buenos valores, pero entramos en overfitting dado que en validación los resultados fueron bastante menores.
#
# A continuación probaremos con embeddding pre-entrenados para ver la performance.

# %% [markdown]
# #### 2.2 - Entrenar el modelo con Embeddings + LSTM con embedings pre-entrenados

# %% [markdown]
# ##### Vamos a descargar los embeddings de fasttext para utilizar en nuestro modelo

# %%
if os.access('fasttext.pkl', os.F_OK) is False:
    url = 'https://drive.google.com/uc?id=1KU5qmAYh3LATMvVgocFDfW-PK3prm1WU&export=download'
    output = 'fasttext.pkl'
    gdown.download(url, output, quiet=False)
else:
    print("Los embeddings fasttext.pkl ya están descargados")
# Out:
# Los embeddings fasttext.pkl ya están descargados

# %% [markdown]
# ##### Generamos la funcion para leer los embeddings

# %%
class WordsEmbeddings(object):
    logger = logging.getLogger(__name__)

    def __init__(self):
        # load the embeddings
        words_embedding_pkl = Path(self.PKL_PATH)
        if not words_embedding_pkl.is_file():
            words_embedding_txt = Path(self.WORD_TO_VEC_MODEL_TXT_PATH)
            assert words_embedding_txt.is_file(), 'Words embedding not available'
            embeddings = self.convert_model_to_pickle()
        else:
            embeddings = self.load_model_from_pickle()
        self.embeddings = embeddings
        # build the vocabulary hashmap
        index = np.arange(self.embeddings.shape[0])
        # Dicctionarios para traducir de embedding a IDX de la palabra
        self.word2idx = dict(zip(self.embeddings['word'], index))
        self.idx2word = dict(zip(index, self.embeddings['word']))

    def get_words_embeddings(self, words):
        words_idxs = self.words2idxs(words)
        return self.embeddings[words_idxs]['embedding']

    def words2idxs(self, words):
        return np.array([self.word2idx.get(word, -1) for word in words])

    def idxs2words(self, idxs):
        return np.array([self.idx2word.get(idx, '-1') for idx in idxs])

    def load_model_from_pickle(self):
        self.logger.debug(
            'loading words embeddings from pickle {}'.format(
                self.PKL_PATH
            )
        )
        max_bytes = 2**28 - 1 # 256MB
        bytes_in = bytearray(0)
        input_size = os.path.getsize(self.PKL_PATH)
        with open(self.PKL_PATH, 'rb') as f_in:
            for _ in range(0, input_size, max_bytes):
                bytes_in += f_in.read(max_bytes)
        embeddings = pickle.loads(bytes_in)
        self.logger.debug('words embeddings loaded')
        return embeddings

    def convert_model_to_pickle(self):
        # create a numpy strctured array:
        # word     embedding
        # U50      np.float32[]
        # word_1   a, b, c
        # word_2   d, e, f
        # ...
        # word_n   g, h, i
        self.logger.debug(
            'converting and loading words embeddings from text file {}'.format(
                self.WORD_TO_VEC_MODEL_TXT_PATH
            )
        )
        structure = [('word', np.dtype('U' + str(self.WORD_MAX_SIZE))),
                     ('embedding', np.float32, (self.N_FEATURES,))]
        structure = np.dtype(structure)
        # load numpy array from disk using a generator
        with open(self.WORD_TO_VEC_MODEL_TXT_PATH, encoding="utf8") as words_embeddings_txt:
            embeddings_gen = (
                (line.split()[0], line.split()[1:]) for line in words_embeddings_txt
                if len(line.split()[1:]) == self.N_FEATURES
            )
            embeddings = np.fromiter(embeddings_gen, structure)
        # add a null embedding
        null_embedding = np.array(
            [('null_embedding', np.zeros((self.N_FEATURES,), dtype=np.float32))],
            dtype=structure
        )
        embeddings = np.concatenate([embeddings, null_embedding])
        # dump numpy array to disk using pickle
        max_bytes = 2**28 - 1 # # 256MB
        bytes_out = pickle.dumps(embeddings, protocol=pickle.HIGHEST_PROTOCOL)
        with open(self.PKL_PATH, 'wb') as f_out:
            for idx in range(0, len(bytes_out), max_bytes):
                f_out.write(bytes_out[idx:idx+max_bytes])
        self.logger.debug('words embeddings loaded')
        return embeddings


class GloveEmbeddings(WordsEmbeddings):
    WORD_TO_VEC_MODEL_TXT_PATH = 'glove.twitter.27B.50d.txt'
    PKL_PATH = 'gloveembedding.pkl'
    N_FEATURES = 50
    WORD_MAX_SIZE = 60


class FasttextEmbeddings(WordsEmbeddings):
    WORD_TO_VEC_MODEL_TXT_PATH = 'cc.en.300.vec'
    PKL_PATH = 'fasttext.pkl'
    N_FEATURES = 300
    WORD_MAX_SIZE = 60

# %% [markdown]
# ##### Generamos la matriz de embeddings

# %%
model_fasttext = FasttextEmbeddings()

# %%
print('Preparamos la matriz de embeddings...')
embed_dim = 300 # fasttext
words_not_found = []

# word_index proviene del tokenizer

nb_words = min(num_words, len(word_index)) 
embedding_matrix = np.zeros((nb_words, embed_dim))
for word, i in word_index.items():
    if i >= nb_words:
        continue
    embedding_vector = model_fasttext.get_words_embeddings(word)[0]
    if (embedding_vector is not None) and len(embedding_vector) > 0:
        embedding_matrix[i] = embedding_vector
    else:
        # words not found in embedding index will be all-zeros.
        words_not_found.append(word)
        print(word)

print('Numemro de word embeddings nulos:', np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# Preparamos la matriz de embeddings...
# Numemro de word embeddings nulos: 2

# %% [markdown]
# ##### Generamos nuestro modelo similar al modelo 1 pero con embeddings pre-entrenados
#
# El mismo consta de:
#
# * Capa de embedings pre-entranada de longitud 300
# * Capa LSTM de 64 unidades Bidireccional
# * Capa LSTM de 96 unidades
# * Capa densa de 128 unidades
# * Capa densa final con activación Softmax y tamaño de salida de 5 (5 clases)

# %%
model3 = Sequential()
model3.add(Embedding(input_dim=vocab_size, output_dim=embed_dim, input_length=in_shape,
                     weights=[embedding_matrix], trainable=False))

model3.add(Bidirectional(LSTM(units=64, return_sequences=True)))
model3.add(Dropout(0.15))
model3.add(LSTM(units=96)) 

model3.add(Dense(units=128, activation='relu'))
model3.add(Dropout(rate=0.2))
model3.add(Dense(units=out_shape, activation='softmax'))

model3.compile(optimizer="adam",
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 115, 300)          1200000
#
#  bidirectional_4 (Bidirectio  (None, 115, 128)         186880
#  nal)
#
#  dropout_5 (Dropout)         (None, 115, 128)          0
#
#  lstm_6 (LSTM)               (None, 96)                86400
#
#  dense_4 (Dense)             (None, 128)               12416
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,486,341
# Trainable params: 286,341
# Non-trainable params: 1,200,000
# _________________________________________________________________

# %%
plot_model(model3, to_file='model_plot3.png', show_shapes=True, show_layer_names=True)

# %%
hist3 = model3.fit(X_train, y_train, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/60
# 453/453 [==============================] - 15s 22ms/step - loss: 1.2240 - accuracy: 0.5533 - val_loss: 1.1723 - val_accuracy: 0.5620
# Epoch 2/60
# 453/453 [==============================] - 10s 22ms/step - loss: 1.1756 - accuracy: 0.5560 - val_loss: 1.1435 - val_accuracy: 0.5669
# Epoch 3/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.1491 - accuracy: 0.5580 - val_loss: 1.1334 - val_accuracy: 0.5669
# Epoch 4/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.1312 - accuracy: 0.5601 - val_loss: 1.1146 - val_accuracy: 0.5661
# Epoch 5/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.1133 - accuracy: 0.5636 - val_loss: 1.1013 - val_accuracy: 0.5780
# Epoch 6/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.0908 - accuracy: 0.5688 - val_loss: 1.1003 - val_accuracy: 0.5678
# Epoch 7/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.0708 - accuracy: 0.5726 - val_loss: 1.0874 - val_accuracy: 0.5805
# Epoch 8/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.0465 - accuracy: 0.5805 - val_loss: 1.0838 - val_accuracy: 0.5769
# Epoch 9/60
# 453/453 [==============================] - 9s 20ms/step - loss: 1.0248 - accuracy: 0.5858 - val_loss: 1.1008 - val_accuracy: 0.5760
# Epoch 10/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.9894 - accuracy: 0.6020 - val_loss: 1.0781 - val_accuracy: 0.5794
# Epoch 11/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.9560 - accuracy: 0.6101 - val_loss: 1.0962 - val_accuracy: 0.5741
# Epoch 12/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0
60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1438 - accuracy: 0.9485 - val_loss: 3.4627 - val_accuracy: 0.5242
# Epoch 42/60
# 453/453 [==============================] - 10s 22ms/step - loss: 0.1466 - accuracy: 0.9464 - val_loss: 3.3894 - val_accuracy: 0.5018
# Epoch 43/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1278 - accuracy: 0.9560 - val_loss: 3.5000 - val_accuracy: 0.4827
# Epoch 44/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1365 - accuracy: 0.9534 - val_loss: 3.6605 - val_accuracy: 0.5197
# Epoch 45/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1214 - accuracy: 0.9560 - val_loss: 3.6757 - val_accuracy: 0.4996
# Epoch 46/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1316 - accuracy: 0.9533 - val_loss: 3.6673 - val_accuracy: 0.5109
# Epoch 47/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1189 - accuracy: 0.9586 - val_loss: 3.7038 - val_accuracy: 0.5305
# Epoch 48/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1331 - accuracy: 0.9534 - val_loss: 3.6675 - val_accuracy: 0.5156
# Epoch 49/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1092 - accuracy: 0.9632 - val_loss: 3.8200 - val_accuracy: 0.5043
# Epoch 50/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1135 - accuracy: 0.9598 - val_loss: 3.8183 - val_accuracy: 0.5098
# Epoch 51/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1006 - accuracy: 0.9631 - val_loss: 3.7688 - val_accuracy: 0.5065
# Epoch 52/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.0991 - accuracy: 0.9656 - val_loss: 3.9498 - val_accuracy: 0.5076
# Epoch 53/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1058 - accuracy: 0.9636 - val_loss: 3.7866 - val_accuracy: 0.4990
# Epoch 54/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1149 - accuracy: 0.9609 - val_loss: 3.7193 - val_accuracy: 0.5029
# Epoch 55/60
# 453/453 [==============================] - 10s 22ms/step - loss: 0.1018 - accuracy: 0.9639 - val_loss: 3.6952 - val_accuracy: 0.4990
# Epoch 56/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1037 - accuracy: 0.9640 - val_loss: 3.9546 - val_accuracy: 0.5035
# Epoch 57/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.1162 - accuracy: 0.9598 - val_loss: 3.8656 - val_accuracy: 0.5137
# Epoch 58/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.0922 - accuracy: 0.9687 - val_loss: 3.9234 - val_accuracy: 0.5161
# Epoch 59/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.0872 - accuracy: 0.9711 - val_loss: 3.9310 - val_accuracy: 0.5068
# Epoch 60/60
# 453/453 [==============================] - 9s 20ms/step - loss: 0.0881 - accuracy: 0.9676 - val_loss: 3.9412 - val_accuracy: 0.5098

# %%
epoch_count = range(1, len(hist3.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist3.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist3.history['val_accuracy'], label='valid')
plt.show()

# %%
model3.evaluate(X_test, y_test)
# Out:
# 142/142 [==============================] - 1s 10ms/step - loss: 3.9805 - accuracy: 0.4957
# [3.9804580211639404, 0.4956943988800049]

# %% [markdown]
# ##### Generamos nuestro modelo similar al modelo 2 pero con embeddings pre-entrenados
#
# El mismo consta de:
#
# * Capa de embedings pre-entranada de longitud 300
# * 2 Capas LSTM de 128 unidades Bidireccional
# * Una capa LSTM de 64 unidades Bidireccional
# * Capa densa de 32 unidades
# * Capa densa final con activación Softmax y tamaño de salida de 5 (5 clases)

# %%
model4 = Sequential()
model4.add(Embedding(input_dim=vocab_size, output_dim=embed_dim, input_length=in_shape,
                     weights=[embedding_matrix], trainable=False))
model4.add(Bidirectional(LSTM(units=128, return_sequences=True)))
model4.add(Dropout(0.15))
model4.add(Bidirectional(LSTM(units=128, return_sequences=True)))
model4.add(Dropout(0.2))
model4.add(Bidirectional(LSTM(units=64)))

model4.add(Dense(units=32, activation='relu'))
model4.add(Dropout(rate=0.2))
model4.add(Dense(units=out_shape, activation='softmax'))

model4.compile(optimizer="adam",
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 115, 300)          1200000
#
#  bidirectional_5 (Bidirectio  (None, 115, 256)         439296
#  nal)
#
#  dropout_7 (Dropout)         (None, 115, 256)          0
#
#  bidirectional_6 (Bidirectio  (None, 115, 256)         394240
#  nal)
#
#  dropout_8 (Dropout)         (None, 115, 256)          0
#
#  bidirectional_7 (Bidirectio  (None, 128)              164352
#  nal)
#
#  dense_6 (Dense)             (None, 32)                4128
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 2,202,181
# Trainable params: 1,002,181
# Non-trainable params: 1,200,000
# _________________________________________________________________

# %%
plot_model(model4, to_file='model_plot4.png', show_shapes=True, show_layer_names=True)

# %%
hist4 = model4.fit(X_train, y_train, epochs=epochs, validation_split=0.2)
# Out:
# Epoch 1/60
# 453/453 [==============================] - 30s 48ms/step - loss: 1.2413 - accuracy: 0.5528 - val_loss: 1.1826 - val_accuracy: 0.5622
# Epoch 2/60
# 453/453 [==============================] - 20s 45ms/step - loss: 1.1918 - accuracy: 0.5537 - val_loss: 1.1477 - val_accuracy: 0.5622
# Epoch 3/60
# 453/453 [==============================] - 20s 43ms/step - loss: 1.1560 - accuracy: 0.5561 - val_loss: 1.1337 - val_accuracy: 0.5628
# Epoch 4/60
# 453/453 [==============================] - 20s 43ms/step - loss: 1.1324 - accuracy: 0.5599 - val_loss: 1.1583 - val_accuracy: 0.5644
# Epoch 5/60
# 453/453 [==============================] - 20s 44ms/step - loss: 1.1086 - accuracy: 0.5636 - val_loss: 1.1382 - val_accuracy: 0.5738
# Epoch 6/60
# 453/453 [==============================] - 20s 44ms/step - loss: 1.0808 - accuracy: 0.5690 - val_loss: 1.0954 - val_accuracy: 0.5758
# Epoch 7/60
# 453/453 [==============================] - 20s 43ms/step - loss: 1.0512 - accuracy: 0.5767 - val_loss: 1.0895 - val_accuracy: 0.5702
# Epoch 8/60
# 453/453 [==============================] - 20s 45ms/step - loss: 1.0233 - accuracy: 0.5821 - val_loss: 1.1344 - val_accuracy: 0.5799
# Epoch 9/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.9885 - accuracy: 0.5925 - val_loss: 1.1031 - val_accuracy: 0.5752
# Epoch 10/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.9522 - accuracy: 0.6030 - val_loss: 1.0997 - val_accuracy: 0.5722
# Epoch 11/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.9066 - accuracy: 0.6184 - val_loss: 1.2750 - val_accuracy: 0.5838
# Epoch 12/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.8647 - accuracy: 0.6259 - val_loss: 1.1941 - val_accuracy: 0.5636
# Epoch 13/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.8135 - accuracy: 0.6493 - val_loss: 1.2356 - val_accuracy: 0.5429
# Epoch 14/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.7694 - accuracy: 0.6694 - val_loss: 1.2352 - val_accuracy: 0.5454
# Epoch 15/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.7135 - accuracy: 0.6917 - val_loss: 1.4498 - val_accuracy: 0.5460
# Epoch 16/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.6584 - accuracy: 0.7169 - val_loss: 1.6229 - val_accuracy: 0.5410
# Epoch 17/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0
60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0951 - accuracy: 0.9689 - val_loss: 3.7349 - val_accuracy: 0.5145
# Epoch 46/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0931 - accuracy: 0.9691 - val_loss: 3.4159 - val_accuracy: 0.4971
# Epoch 47/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0907 - accuracy: 0.9703 - val_loss: 3.5351 - val_accuracy: 0.5092
# Epoch 48/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0859 - accuracy: 0.9718 - val_loss: 3.7014 - val_accuracy: 0.4841
# Epoch 49/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0926 - accuracy: 0.9691 - val_loss: 3.6921 - val_accuracy: 0.5134
# Epoch 50/60
# 453/453 [==============================] - 21s 45ms/step - loss: 0.0897 - accuracy: 0.9702 - val_loss: 3.7042 - val_accuracy: 0.5062
# Epoch 51/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0906 - accuracy: 0.9694 - val_loss: 3.5150 - val_accuracy: 0.5043
# Epoch 52/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.0831 - accuracy: 0.9714 - val_loss: 3.5687 - val_accuracy: 0.4999
# Epoch 53/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.0720 - accuracy: 0.9779 - val_loss: 3.5334 - val_accuracy: 0.5023
# Epoch 54/60
# 453/453 [==============================] - 20s 44ms/step - loss: 0.0766 - accuracy: 0.9759 - val_loss: 3.7051 - val_accuracy: 0.5195
# Epoch 55/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.0803 - accuracy: 0.9736 - val_loss: 3.6044 - val_accuracy: 0.4935
# Epoch 56/60
# 453/453 [==============================] - 21s 46ms/step - loss: 0.0852 - accuracy: 0.9704 - val_loss: 3.6254 - val_accuracy: 0.5043
# Epoch 57/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.0699 - accuracy: 0.9769 - val_loss: 3.6461 - val_accuracy: 0.5253
# Epoch 58/60
# 453/453 [==============================] - 20s 43ms/step - loss: 0.0805 - accuracy: 0.9737 - val_loss: 3.4240 - val_accuracy: 0.5023
# Epoch 59/60
# 453/453 [==============================] - 19s 43ms/step - loss: 0.0779 - accuracy: 0.9752 - val_loss: 3.5429 - val_accuracy: 0.5070
# Epoch 60/60
# 453/453 [==============================] - 19s 43ms/step - loss: 0.0658 - accuracy: 0.9788 - val_loss: 3.6447 - val_accuracy: 0.5137

# %%
epoch_count = range(1, len(hist4.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist4.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist4.history['val_accuracy'], label='valid')
plt.show()

# %%
model4.evaluate(X_test, y_test)
# Out:
# 142/142 [==============================] - 3s 19ms/step - loss: 3.5611 - accuracy: 0.5220
# [3.5610764026641846, 0.5219695568084717]

# %% [markdown]
# Los resultados fueron similares con ambos modelos.
#
# Como punto negativo los resultados contra los modelos con embedding entrenados en la misma red fueron algo menores.
# Como punto positivo el tiempo de entrenamiento fue algo menor.

# %% [markdown]
# #### Resultados y conclusiones

# %% [markdown]
# * Con modelos más simples y menos profundos se entró más rápidamente en zona de overffitng. Ambos modelos resultaron complejos y no aprendieron bien, a pesar de las epochs de entrenamiento utilizadas.
# * Con los embeddings pre-entrenados de fastex los tiempos de entrenamiento fueron menores, pero los resultados obtenidos fueron algo peores. Se vio que entrenar los embeddings considerando el contexto propio del problema ayudó a tener mejores resultados, aún cuando la longitud de los embeddings fueron menores (Ventajas: mejores resultados y embeddings más pequeños).
# * Se debe considerar que las clases estaban desbalanceadas. En una notebook aparte (Desafio_5_oversampling) se muestra el mismo proceso ejecuta acá pero con oversampling y simplificando los modelos. Con esos ajustes los resultados obtenidos fueron mucho mejores.
